# %%
#Thanks to Luciano Prevedello and Barbaros Selner Erdal.
#https://www.kaggle.com/code/felipekitamura/head-ct-hemorrhage-kernel/notebook
##First of all, we are going to load the images and labels
from glob import glob
import os
import pandas as pd 
import cv2
import numpy as np

# Now we define the dimensions of our images.

img_width, img_height = 128, 128

train_files = sorted(glob('C:\\Users\\charl\\Documents\\College\\Spring 2022\\Thesis\\Data\\Hemorrage\\Train\\*.png'))
train_labels = pd.read_csv('C:\\Users\\charl\\Documents\\College\\Spring 2022\\Thesis\\Data\\Hemorrage\\Train\\labels.csv')[' hemorrhage'].tolist()

test_files = sorted(glob('C:\\Users\\charl\\Documents\\College\\Spring 2022\\Thesis\\Data\\Hemorrage\\Test\\*.png'))
test_labels = pd.read_csv('C:\\Users\\charl\\Documents\\College\\Spring 2022\\Thesis\\Data\\Hemorrage\\Test\\labels.csv')[' hemorrhage'].tolist()

recon_test_files = sorted(glob('C:\\Users\\charl\\Documents\\College\\Spring 2022\\Thesis\\Data\\Hemorrage\\Reconstructed Test\\*.png'))
recon_test_labels = pd.read_csv('C:\\Users\\charl\\Documents\\College\\Spring 2022\\Thesis\\Data\\Hemorrage\\Reconstructed Test\\labels.csv')[' hemorrhage'].tolist()


train_images = np.empty((len(train_files), img_width, img_height))
test_images = np.empty((len(test_files), img_width, img_height))
recon_test_images = np.empty((len(recon_test_files), img_width, img_height))

for i, _file in enumerate(train_files):
    train_images[i, :, :] = cv2.resize(cv2.imread(_file, 0), (img_width, img_height))
for i, _file in enumerate(test_files):
    test_images[i, :, :] = cv2.resize(cv2.imread(_file, 0), (img_width, img_height))
for i, _file in enumerate(recon_test_files):
    recon_test_images[i, :, :] = cv2.resize(cv2.imread(_file, 0), (img_width, img_height))      
    
print ('\033[1m' + 'Ready for next step!')
# Out:
# Ready for next step!

# %%
#Now we split the dataset into train (80%), validation (10%) and test (10%) sets.
from sklearn.model_selection import train_test_split
import numpy as np

val_images, test_images, val_labels, test_labels = train_test_split(test_images, test_labels, test_size=0.5, random_state=1)

print((len(train_images), len(val_images), len(test_images)))
# Out:
# (169, 15, 16)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import backend as K
import tensorflow as tf
input_shape = (img_width, img_height, 1)

SIIM_custom_model = None

SIIM_custom_model = Sequential()

#Below we have the first Convolutional Layer

SIIM_custom_model.add(Conv2D(32, (3, 3), input_shape=input_shape))
SIIM_custom_model.add(Activation('relu'))

#We then add a MaxPool layer, which will reduce the size of the output of the first conv layer in 75%.
#This is performed to avoid an exagerated increase in the number of parameters of the network.
#Don't worry if you do not understand in detail each one of these operations right now. Try to focus on the big picture.

SIIM_custom_model.add(MaxPooling2D(pool_size=(2, 2)))

#We will add more convolutional layers, followed by MaxPool layers

SIIM_custom_model.add(Conv2D(32, (3, 3)))
SIIM_custom_model.add(Activation('relu'))
SIIM_custom_model.add(MaxPooling2D(pool_size=(2, 2)))

SIIM_custom_model.add(Conv2D(64, (3, 3)))
SIIM_custom_model.add(Activation('relu'))
SIIM_custom_model.add(MaxPooling2D(pool_size=(2, 2)))

#Finally, we will add two dense layers, or 'Fully Connected Layers'.
#These layers are classical neural nets, without convolutions.

SIIM_custom_model.add(Flatten())
SIIM_custom_model.add(Dense(64))
SIIM_custom_model.add(Activation('relu'))

#Dropout is an overfitting reduction technique.

SIIM_custom_model.add(Dropout(0.5))

#Now, we will set the output o the network.
#The Dense function has the argument "1" because the net output is the hematoma x non-hematoma classification

SIIM_custom_model.add(Dense(1))

#The output is either 0 or 1 and this can be obtained with a sigmoid function.

SIIM_custom_model.add(Activation('sigmoid'))

#Let's compile the network.

SIIM_custom_model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

print ('\033[1m' + 'Ready for next step!')
# Out:
# Ready for next step!

# %%
import warnings
warnings.filterwarnings('ignore')

nb_train_samples = len(train_images)
nb_validation_samples = len(val_images)
epochs = 100
batch_size = 10


# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.0,
    zoom_range=0.1,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)

# this is the augmentation configuration we will use for validation:
val_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow(
    train_images[..., np.newaxis],
    train_labels,
    batch_size=batch_size)

validation_generator = val_datagen.flow(
    val_images[..., np.newaxis],
    val_labels,
    batch_size=batch_size)

print ('\033[1m' + 'Ready for next step!')
# Out:
# Ready for next step!

# %%
history = SIIM_custom_model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7364 - accuracy: 0.49 - 5s 28ms/step - loss: 0.7278 - accuracy: 0.4906 - val_loss: 0.6710 - val_accuracy: 0.9000
# Epoch 2/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6877 - accuracy: 0.5975 - val_loss: 0.7023 - val_accuracy: 0.4000
# Epoch 3/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6628 - accuracy: 0.6101 - val_loss: 0.8149 - val_accuracy: 0.3000
# Epoch 4/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6235 - accuracy: 0.6352 - val_loss: 0.5799 - val_accuracy: 0.8000
# Epoch 5/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6206 - accuracy: 0.6667 - val_loss: 0.5140 - val_accuracy: 0.8000
# Epoch 6/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6201 - accuracy: 0.6730 - val_loss: 0.4980 - val_accuracy: 0.8000
# Epoch 7/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5619 - accuracy: 0.7547 - val_loss: 0.7048 - val_accuracy: 0.6000
# Epoch 8/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5076 - accuracy: 0.7610 - val_loss: 0.5000 - val_accuracy: 0.7000
# Epoch 9/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4968 - accuracy: 0.7484 - val_loss: 0.6505 - val_accuracy: 0.7000
# Epoch 10/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5124 - accuracy: 0.7610 - val_loss: 0.5223 - val_accuracy: 0.7000
# Epoch 11/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5094 - accuracy: 0.7736 - val_loss: 0.5120 - val_accuracy: 0.7000
# Epoch 12/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4680 - accuracy: 0.8050 - val_loss: 0.5719 - val_accuracy: 0.7000
# Epoch 13/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5004 - accuracy: 0.7358 - val_loss: 0.4529 - val_accuracy: 0.8000
# Epoch 14/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4119 - accuracy: 0.8113 - val_loss: 0.5797 - val_accuracy: 0.7000
# Epoch 15/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.5260 - accuracy: 0.7987 - val_loss: 0.4648 - val_accuracy: 0.8000
# Epoch 16/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4588 - accuracy: 0.8000 - val_loss: 0.5576 - val_accuracy: 0.9000
# Epoch 17/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4971 - accuracy: 0.7799 - val_loss: 0.4198 - val_accuracy: 0.9000
# Epoch 18/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4304 - accuracy: 0.8176 - val_loss: 0.4727 - val_accuracy: 0.9000
# Epoch 19/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4022 - accuracy: 0.7925 - val_loss: 0.5512 - val_accuracy: 0.6000
# Epoch 20/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3970 - accuracy: 0.8491 - val_loss: 0.6205 - val_accuracy: 0.7000
# Epoch 21/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4326 - accuracy: 0.7987 - val_loss: 0.5166 - val_accuracy: 0.7000
# Epoch 22/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3649 - accuracy: 0.8428 - val_loss: 0.8316 - val_accuracy: 0.7000
# Epoch 23/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4742 - accuracy: 0.7987 - val_loss: 0.2714 - val_accuracy: 1.0000
# Epoch 24/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3961 - accuracy: 0.8302 - val_loss: 0.5271 - val_accuracy: 0.6000
# Epoch 25/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4091 - accuracy: 0.8302 - val_loss: 0.5375 - val_accuracy: 0.8000
# Epoch 26/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4163 - accuracy: 0.8302 - val_loss: 0.3472 - val_accuracy: 0.9000
# Epoch 27/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3860 - accuracy: 0.8491 - val_loss: 0.3859 - val_accuracy: 0.9000
# Epoch 28/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4096 - accuracy: 0.7925 - val_loss: 0.3744 - val_accuracy: 0.8000
# Epoch 29/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4345 - accuracy: 0.8050 - val_loss: 0.3665 - val_accuracy: 0.8000
# Epoch 30/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3301 - accuracy: 0.8491 - val_loss: 0.3766 - val_accuracy: 0.8000
# Epoch 31/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2822 - accuracy: 0.8742 - val_loss: 0.6916 - val_accuracy: 0.8000
# Epoch 32/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3569 - accuracy: 0.8313 - val_loss: 0.3431 - val_accuracy: 0.8000
# Epoch 33/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3218 - accuracy: 0.8679 - val_loss: 0.3979 - val_accuracy: 0.8000
# Epoch 34/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3163 - accuracy: 0.8805 - val_loss: 0.5992 - val_accuracy: 0.7000
# Epoch 35/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2949 - accuracy: 0.8805 - val_loss: 0.3424 - val_accuracy: 0.8000
# Epoch 36/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3183 - accuracy: 0.8742 - val_loss: 0.4872 - val_accuracy: 0.7000
# Epoch 37/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3255 - accuracy: 0.8679 - val_loss: 0.4943 - val_accuracy: 0.7000
# Epoch 38/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2311 - accuracy: 0.8931 - val_loss: 0.3642 - val_accuracy: 0.9000
# Epoch 39/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3324 - accuracy: 0.8679 - val_loss: 0.2332 - val_accuracy: 0.9000
# Epoch 40/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2646 - accuracy: 0.8994 - val_loss: 0.5446 - val_accuracy: 0.7000
# Epoch 41/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2788 - accuracy: 0.8805 - val_loss: 0.6229 - val_accuracy: 0.7000
# Epoch 42/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2457 - accuracy: 0.8931 - val_loss: 0.1862 - val_accuracy: 0.9000
# Epoch 43/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2523 - accuracy: 0.8868 - val_loss: 0.4816 - val_accuracy: 0.7000
# Epoch 44/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2628 - accuracy: 0.8931 - val_loss: 0.3607 - val_accuracy: 0.7000
# Epoch 45/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2251 - accuracy: 0.9182 - val_loss: 0.4203 - val_accuracy: 0.7000
# Epoch 46/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2980 - accuracy: 0.8750 - val_loss: 0.3425 - val_accuracy: 0.8000
# Epoch 47/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1914 - accuracy: 0.9371 - val_loss: 0.4788 - val_accuracy: 0.7000
# Epoch 48/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2608 - accuracy: 0.8868 - val_loss: 0.1827 - val_accuracy: 0.9000
# Epoch 49/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2041 - accuracy: 0.8994 - val_loss: 0.2278 - val_accuracy: 0.8000
# Epoch 50/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2389 - accuracy: 0.9182 - val_loss: 0.4324 - val_accuracy: 0.8000
# Epoch 51/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2446 - accuracy: 0.9057 - val_loss: 0.4155 - val_accuracy: 0.9000
# Epoch 52/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2830 - accuracy: 0.9057 - val_loss: 0.2289 - val_accuracy: 0.9000
# Epoch 53/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2919 - accuracy: 0.8805 - val_loss: 0.2720 - val_accuracy: 0.8000
# Epoch 54/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1997 - accuracy: 0.8994 - val_loss: 0.1917 - val_accuracy: 0.8000
# Epoch 55/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2298 - accuracy: 0.9057 - val_loss: 0.7332 - val_accuracy: 0.7000
# Epoch 56/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2434 - accuracy: 0.9308 - val_loss: 0.4084 - val_accuracy: 0.7000
# Epoch 57/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1499 - accuracy: 0.9371 - val_loss: 0.6692 - val_accuracy: 0.7000
# Epoch 58/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2179 - accuracy: 0.9182 - val_loss: 0.6082 - val_accuracy: 0.8000
# Epoch 59/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1745 - accuracy: 0.9623 - val_loss: 0.4770 - val_accuracy: 0.7000
# Epoch 60/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2433 - accuracy: 0.8994 - val_loss: 0.2575 - val_accuracy: 0.8000
# Epoch 61/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1986 - accuracy: 0.9308 - val_loss: 0.2188 - val_accuracy: 0.9000
# Epoch 62/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1482 - accuracy: 0.9434 - val_loss: 0.2010 - val_accuracy: 0.9000
# Epoch 63/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2455 - accuracy: 0.9182 - val_loss: 0.5402 - val_accuracy: 0.8000
# Epoch 64/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1930 - accuracy: 0.9182 - val_loss: 0.5628 - val_accuracy: 0.7000
# Epoch 65/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2079 - accuracy: 0.9245 - val_loss: 0.2141 - val_accuracy: 0.9000
# Epoch 66/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1986 - accuracy: 0.9182 - val_loss: 0.1757 - val_accuracy: 0.9000
# Epoch 67/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1249 - accuracy: 0.9434 - val_loss: 0.5564 - val_accuracy: 0.8000
# Epoch 68/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1983 - accuracy: 0.9434 - val_loss: 0.2920 - val_accuracy: 0.8000
# Epoch 69/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1877 - accuracy: 0.9119 - val_loss: 0.1140 - val_accuracy: 1.0000
# Epoch 70/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1538 - accuracy: 0.9497 - val_loss: 0.4758 - val_accuracy: 0.7000
# Epoch 71/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1385 - accuracy: 0.9434 - val_loss: 0.2696 - val_accuracy: 0.9000
# Epoch 72/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2254 - accuracy: 0.9182 - val_loss: 0.2719 - val_accuracy: 0.8000
# Epoch 73/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1490 - accuracy: 0.9371 - val_loss: 0.7352 - val_accuracy: 0.7000
# Epoch 74/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2090 - accuracy: 0.9434 - val_loss: 0.3263 - val_accuracy: 0.8000
# Epoch 75/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0981 - accuracy: 0.9686 - val_loss: 0.3249 - val_accuracy: 0.7000
# Epoch 76/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1812 - accuracy: 0.9308 - val_loss: 0.2603 - val_accuracy: 0.8000
# Epoch 77/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1641 - accuracy: 0.9434 - val_loss: 0.1858 - val_accuracy: 0.9000
# Epoch 78/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1624 - accuracy: 0.9434 - val_loss: 0.3098 - val_accuracy: 0.8000
# Epoch 79/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1464 - accuracy: 0.9623 - val_loss: 0.1436 - val_accuracy: 1.0000
# Epoch 80/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1337 - accuracy: 0.9497 - val_loss: 0.3831 - val_accuracy: 0.8000
# Epoch 81/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1828 - accuracy: 0.9245 - val_loss: 0.2161 - val_accuracy: 0.9000
# Epoch 82/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1486 - accuracy: 0.9623 - val_loss: 0.1697 - val_accuracy: 0.9000
# Epoch 83/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1493 - accuracy: 0.9434 - val_loss: 0.1250 - val_accuracy: 0.9000
# Epoch 84/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1808 - accuracy: 0.9371 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 85/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1305 - accuracy: 0.9560 - val_loss: 0.6607 - val_accuracy: 0.7000
# Epoch 86/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1522 - accuracy: 0.9563 - val_loss: 0.4084 - val_accuracy: 0.8000
# Epoch 87/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0994 - accuracy: 0.9623 - val_loss: 0.3490 - val_accuracy: 0.9000
# Epoch 88/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1194 - accuracy: 0.9560 - val_loss: 0.3320 - val_accuracy: 0.7000
# Epoch 89/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1525 - accuracy: 0.9560 - val_loss: 0.5191 - val_accuracy: 0.7000
# Epoch 90/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1817 - accuracy: 0.9182 - val_loss: 0.4378 - val_accuracy: 0.9000
# Epoch 91/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1359 - accuracy: 0.9560 - val_loss: 0.6159 - val_accuracy: 0.6000
# Epoch 92/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1243 - accuracy: 0.9560 - val_loss: 0.5456 - val_accuracy: 0.9000
# Epoch 93/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1827 - accuracy: 0.9245 - val_loss: 0.2693 - val_accuracy: 0.8000
# Epoch 94/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1178 - accuracy: 0.9686 - val_loss: 0.7186 - val_accuracy: 0.7000
# Epoch 95/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1530 - accuracy: 0.9560 - val_loss: 0.2413 - val_accuracy: 0.9000
# Epoch 96/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1801 - accuracy: 0.9371 - val_loss: 0.6237 - val_accuracy: 0.8000
# Epoch 97/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1090 - accuracy: 0.9623 - val_loss: 1.1434 - val_accuracy: 0.7000
# Epoch 98/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1197 - accuracy: 0.9497 - val_loss: 0.2238 - val_accuracy: 0.9000
# Epoch 99/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1309 - accuracy: 0.9497 - val_loss: 0.5215 - val_accuracy: 0.8000
# Epoch 100/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1406 - accuracy: 0.9623 - val_loss: 0.2723 - val_accuracy: 0.8000

# %%
import matplotlib.pyplot as plt
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\charl\Documents\College\Spring 2022\Thesis\Code\head-ct-hemorrhage-kernel.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/charl/Documents/College/Spring%202022/Thesis/Code/head-ct-hemorrhage-kernel.ipynb#ch0000005?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/charl/Documents/College/Spring%202022/Thesis/Code/head-ct-hemorrhage-kernel.ipynb#ch0000005?line=1'>2</a> # Plot training & validation accuracy values
# ----> <a href='vscode-notebook-cell:/c%3A/Users/charl/Documents/College/Spring%202022/Thesis/Code/head-ct-hemorrhage-kernel.ipynb#ch0000005?line=2'>3</a> plt.plot(history.history['acc'])
#       <a href='vscode-notebook-cell:/c%3A/Users/charl/Documents/College/Spring%202022/Thesis/Code/head-ct-hemorrhage-kernel.ipynb#ch0000005?line=3'>4</a> plt.plot(history.history['val_acc'])
#       <a href='vscode-notebook-cell:/c%3A/Users/charl/Documents/College/Spring%202022/Thesis/Code/head-ct-hemorrhage-kernel.ipynb#ch0000005?line=4'>5</a> plt.title('Model accuracy')
#
# KeyError: 'acc'

# %%
#Now we evaluate on the test set. Remember to make pixels between [0, 1] by dividing by 255.
y_preds = []
for index in range(0,len(test_images)):
    y_preds.append(SIIM_custom_model.predict((test_images[index] // 255).reshape(-1, img_height, img_width, 1), test_labels[index]))

m = tf.keras.metrics.BinaryAccuracy()
m.update_state(test_labels, y_preds)
print(f'Result of original test data: {m.result().numpy()}')

for index in range(0,len(test_images)):
    y_preds.append(SIIM_custom_model.predict((recon_test_images[index] // 255).reshape(-1, img_height, img_width, 1), recon_test_labels[index]))

m = tf.keras.metrics.BinaryAccuracy()
m.update_state(recon_test_labels, y_preds)
print(f'Result of reconstructed test data: {m.result().numpy()}')
# Out:
# Result of original test data: 0.75
# Result of reconstructed test data: 0.5483871102333069
